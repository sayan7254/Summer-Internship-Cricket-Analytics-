# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('M2.csv')
df.head()
# Out:
#                  Date         Batting Team      Bowling Team          Striker  \
# 0  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Abhishek Sharma
# 1  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Abhishek Sharma
# 2  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Abhishek Sharma
# 3  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Abhishek Sharma
# 4  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Abhishek Sharma
#
#    Non-Striker            Bowler  Innings  Unique  Over Number  Over Ball  \
# 0  Travis Head  Fazalhaq Farooqi        1     0.1            1          1
# 1  Travis Head  Fazalhaq Farooqi        1     0.2            1          2
# 2  Travis Head  Fazalhaq Farooqi        1     0.3            1          3
# 3  Travis Head  Fazalhaq Farooqi        1     0.4            1          4
# 4  Travis Head  Fazalhaq Farooqi        1     0.5            1          5
#
# ...

# %%
#Calculating the Given Parameters for the Middle Overs
df.columns
# Out:
# Index(['Date', 'Batting Team', 'Bowling Team', 'Striker', 'Non-Striker',
#        'Bowler', 'Innings', 'Unique', 'Over Number', 'Over Ball', 'Runs',
#        'Wides', 'Team Runs', 'Remaining Overs', 'Lead By', 'Trail By',
#        'Fall Of Wickets', 'Day', 'Session', 'Leg Byes', 'No Balls', 'Balls',
#        'Byes', 'Remaining Balls', 'Remaining Runs', 'Run Rate', 'Batter Sixes',
#        'Batter Runs', 'Batter Fours', 'Batter Balls', 'Batter Total Runs',
#        'Dismissal Type', 'Dismissal Fielder', 'On Field Minutes', 'Shot Angle',
#        'Shot Magnitude', 'Wagon Position', 'Pitching Length', 'Pitching Line',
#        'Shot Connection', 'False Shot', 'Feet Movement', 'Shot Type',
#        'Delivery Type', 'Bowling Side', 'Bowling Type', 'Bowling Hand',
#        'Catch Difficulty', 'Bounce_Angle', 'Pitch_x', 'Pitch_y', 'Friction',
#        'Restitution', 'Deviation', 'Reaction Time', 'Release Speed', 'Swing',
#        'Swing Distance', 'Six Distance'],
#       dtype='object')

# %%
df_mid=df[(df['Over Number']>6) & (df['Over Number']<=15)]
df_mid.head()
# Out:
#                   Date         Batting Team      Bowling Team       Striker  \
# 40  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Ishan Kishan
# 41  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Ishan Kishan
# 42  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals  Ishan Kishan
# 43  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals   Travis Head
# 44  2025-3-24 15:30:00  Sunrisers Hyderabad  Rajasthan Royals   Travis Head
#
#      Non-Striker          Bowler  Innings  Unique  Over Number  Over Ball  \
# 40   Travis Head  Sandeep Sharma        1     6.1            7          1
# 41   Travis Head  Sandeep Sharma        1     6.2            7          2
# 42   Travis Head  Sandeep Sharma        1     6.3            7          3
# 43  Ishan Kishan  Sandeep Sharma        1     6.4            7          4
# 44  Ishan Kishan  Sandeep Sharma        1     6.5            7          5
#
# ...

# %%
team=pd.DataFrame(df.groupby('Batting Team')['Batter Runs'].sum())
team
# Out:
#                      Batter Runs
# Batting Team
# Rajasthan Royals             229
# Sunrisers Hyderabad          268

# %%
team['Balls Faced']=pd.DataFrame(df[df['Wides']==0].groupby('Batting Team')['Balls'].count())
team
# Out:
#                      Batter Runs  Balls Faced
# Batting Team
# Rajasthan Royals             229          122
# Sunrisers Hyderabad          268          123

# %%
team['SR']=team['Batter Runs']/team['Balls Faced']
team
# Out:
#                      Batter Runs  Balls Faced        SR
# Batting Team
# Rajasthan Royals             229          122  1.877049
# Sunrisers Hyderabad          268          123  2.178862

# %%
team['Economy']=team['Batter Runs']/8
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625
# Sunrisers Hyderabad          268          123  2.178862   33.500

# %%
team['Sixes'] = pd.DataFrame(df[df['Runs'] == 6].groupby('Batting Team').size())
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12

# %%
team['Fours']=pd.DataFrame(df[df['Runs']==4].groupby('Batting Team').size())
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  Fours
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12     34

# %%
team['Boundaries']=team['Sixes']+team['Fours']
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries
# Batting Team
# Rajasthan Royals        18          36
# Sunrisers Hyderabad     34          46

# %%
team['Dismissal Count']=df[df['Dismissal Type'].notna()].groupby('Batting Team').size()
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count
# Batting Team
# Rajasthan Royals        18          36                6
# Sunrisers Hyderabad     34          46                6

# %%
team['Batting Avg']=team['Batter Runs']/team['Dismissal Count']
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count  Batting Avg
# Batting Team
# Rajasthan Royals        18          36                6    38.166667
# Sunrisers Hyderabad     34          46                6    44.666667

# %%
team['Total shot']=pd.DataFrame(df.groupby('Batting Team')['False Shot'].count())
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count  Batting Avg  \
# Batting Team
# Rajasthan Royals        18          36                6    38.166667
# Sunrisers Hyderabad     34          46                6    44.666667
#
#                      Total shot
# Batting Team
# Rajasthan Royals            129
# Sunrisers Hyderabad         133

# %%
team['Fal Shot']=pd.DataFrame(df[df['False Shot']==1].groupby('Batting Team')['False Shot'].count())
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count  Batting Avg  \
# Batting Team
# Rajasthan Royals        18          36                6    38.166667
# Sunrisers Hyderabad     34          46                6    44.666667
#
#                      Total shot  Fal Shot
# Batting Team
# Rajasthan Royals            129        58
# Sunrisers Hyderabad         133        63

# %%
team['False Shot Percentages']=(team['Fal Shot']*100/team['Total shot'])
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count  Batting Avg  \
# Batting Team
# Rajasthan Royals        18          36                6    38.166667
# Sunrisers Hyderabad     34          46                6    44.666667
#
#                      Total shot  Fal Shot  False Shot Percentages
# Batting Team
# Rajasthan Royals            129        58               44.961240
# Sunrisers Hyderabad         133        63               47.368421

# %%
team['Boundary Rate']=team['Boundaries']/team['Balls Faced']
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count  Batting Avg  \
# Batting Team
# Rajasthan Royals        18          36                6    38.166667
# Sunrisers Hyderabad     34          46                6    44.666667
#
#                      Total shot  Fal Shot  False Shot Percentages  \
# Batting Team
# Rajasthan Royals            129        58               44.961240
# Sunrisers Hyderabad         133        63               47.368421
#
#                      Boundary Rate
# Batting Team
# Rajasthan Royals          0.295082
# Sunrisers Hyderabad       0.373984

# %%
team['Dismissal Rate']=team['Dismissal Count']/team['Balls Faced']
team
# Out:
#                      Batter Runs  Balls Faced        SR  Economy  Sixes  \
# Batting Team
# Rajasthan Royals             229          122  1.877049   28.625     18
# Sunrisers Hyderabad          268          123  2.178862   33.500     12
#
#                      Fours  Boundaries  Dismissal Count  Batting Avg  \
# Batting Team
# Rajasthan Royals        18          36                6    38.166667
# Sunrisers Hyderabad     34          46                6    44.666667
#
#                      Total shot  Fal Shot  False Shot Percentages  \
# Batting Team
# Rajasthan Royals            129        58               44.961240
# Sunrisers Hyderabad         133        63               47.368421
#
#                      Boundary Rate  Dismissal Rate
# Batting Team
# Rajasthan Royals          0.295082         0.04918
# Sunrisers Hyderabad       0.373984         0.04878

# %%
legal_balls = df[(df["Wides"] == 0) & (df["No Balls"] == 0)]
rotating_balls = legal_balls[legal_balls["Runs"].isin([1, 2, 3])]
total_balls = legal_balls.groupby("Batting Team").size()
rotating_counts = rotating_balls.groupby("Batting Team").size()
strike_rotation = (rotating_counts / total_balls * 100)
strike_rotation
# Out:
# Batting Team
# Rajasthan Royals       37.500000
# Sunrisers Hyderabad    41.666667
# dtype: float64
